# %%
import pandas as pd
small = pd.read_csv('data/results/text-embedding-3-small.csv')

# %%
small = small[small['Reranker'] == 'bge reranker']
small = small[small['Tokenizer'] == 'visobert']
small = small[small['Vectorstore'] != 'text-large']

# %%
small
# Out:
#    Tokenizer Vectorstore      Reranker      Mode  Avg Precision@10  \
# 36  visobert      halong  bge reranker      bm25            0.4391
# 37  visobert      halong  bge reranker  semantic            0.3038
# 38  visobert      halong  bge reranker    hybrid            0.4474
# 39  visobert  text-small  bge reranker      bm25            0.4391
# 40  visobert  text-small  bge reranker  semantic            0.2803
# 41  visobert  text-small  bge reranker    hybrid            0.4397
#
#     Avg Recall@10  Avg F1-Score@10  Avg MRR@10  Hit Rate@10  Avg NDCG@10
# 36         0.6195           0.4466      0.8969       0.9672       0.8778
# 37         0.4054           0.3022      0.8108       0.8689       0.6846
# 38         0.6344           0.4538      0.9139       0.9672       0.9424
# 39         0.6195           0.4466      0.8969       0.9672       0.8778
# 40         0.3854           0.2803      0.7239       0.8361       0.6110
# ...

# %%
large = pd.read_csv('data/results/text-embedding-3-large.csv')

# %%
large = large[large['Reranker'] == 'bge reranker']
large = large[large['Tokenizer'] == 'visobert']
large = large[large['Vectorstore'] != 'text-large']

# %%
large
# Out:
#    Tokenizer Vectorstore      Reranker      Mode  Avg Precision@10  \
# 36  visobert      halong  bge reranker      bm25            0.4391
# 37  visobert      halong  bge reranker  semantic            0.2815
# 38  visobert      halong  bge reranker    hybrid            0.4813
# 39  visobert  text-small  bge reranker      bm25            0.4391
# 40  visobert  text-small  bge reranker  semantic            0.2591
# 41  visobert  text-small  bge reranker    hybrid            0.4850
#
#     Avg Recall@10  Avg F1-Score@10  Avg MRR@10  Hit Rate@10  Avg NDCG@10
# 36         0.6195           0.4466      0.8969       0.9672       0.8778
# 37         0.3582           0.2734      0.7684       0.8361       0.6346
# 38         0.6113           0.4584      0.9126       0.9672       0.9961
# 39         0.6195           0.4466      0.8969       0.9672       0.8778
# 40         0.3658           0.2598      0.7097       0.8033       0.5653
# ...
